# %% [markdown]
# <a href="https://colab.research.google.com/github/045036/DEVP_Nishitayadav_045036/blob/main/data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data_cleaned.csv')
df
# Out:
#     PublishedAgo  Rating                    Employer  \
# 0             5d     4.3    KGS Technology Group Inc
# 1             4d     4.2                    QSC, LLC
# 2           30d+     4.2      MIT Lincoln Laboratory
# 3             6d     4.2  Hewlett Packard Enterprise
# 4             2d     3.3                    Oran Inc
# ..           ...     ...                         ...
# 606           9d     4.0                      PayPal
# 607          12d     3.5                Eightfold.AI
# 608         30d+     4.4                       Adobe
# 609         30d+     4.5                       Curai
# 610           5d     4.3                   Microsoft
#
#                                JobTitle  Founded                    Type  \
# 0              Junior Software Engineer   2008.0       Company - Private
# 1                           AI Engineer   1968.0       Company - Private
# 2                           AI Engineer   1951.0  Nonprofit Organization
# 3                  AI Solution Engineer   2015.0        Company - Public
# 4                  AI/ML Cloud Engineer   2004.0       Company - Private
# ..                                  ...      ...                     ...
# 606        AI Machine Learning Engineer   1998.0        Company - Public
# 607           Machine Learning Engineer   2016.0       Company - Private
# 608         Research Scientist/Engineer   1982.0        Company - Public
# 609  Machine Learning Engineer (Remote)   2017.0       Company - Private
# 610                   Software Engineer   1975.0        Company - Public
#
#                                     Industry                   Sector  \
# 0    Information Technology Support Services   Information Technology
# 1                  Electronics Manufacturing            Manufacturing
# 2                        Aerospace & Defense      Aerospace & Defense
# 3    Information Technology Support Services   Information Technology
# 4                        Business Consulting  Management & Consulting
# ..                                       ...                      ...
# 606                  Internet & Web Services   Information Technology
# 607  Enterprise Software & Network Solutions   Information Technology
# 608            Computer Hardware Development   Information Technology
# 609               Hospitals & Health Clinics               Healthcare
# 610            Computer Hardware Development   Information Technology
#
#      MinSalary  MaxSalary           City   State        Country  MinSize  \
# 0         60.0       80.0         Remote  Remote         Remote     51.0
# 1        102.0      147.0         Remote  Remote         Remote    501.0
# 2         94.0      138.0      Lexington      MA  United States   1001.0
# 3        123.0      283.0       San Jose      CA  United States  10000.0
# 4        140.0      140.0         Remote  Remote         Remote      1.0
# ..         ...        ...            ...     ...            ...      ...
# 606       97.0      234.0       San Jose      CA  United States  10000.0
# 607      121.0      163.0    Santa Clara      CA  United States    501.0
# 608      121.0      239.0       San Jose      CA  United States  10000.0
# 609      150.0      200.0  San Francisco      CA  United States     51.0
# 610       76.0      152.0        Redmond      WA  United States  10000.0
#
#      MaxSize    MinRevenue    MaxRevenue
# 0      200.0  1.000000e+06  5.000000e+06
# 1     1000.0           NaN           NaN
# 2     5000.0           NaN           NaN
# 3    10000.0           NaN           NaN
# 4       50.0  1.000000e+06  5.000000e+06
# ..       ...           ...           ...
# 606  10000.0  1.000000e+10  1.000000e+10
# 607   1000.0           NaN           NaN
# 608  10000.0  5.000000e+09  1.000000e+10
# 609    200.0           NaN           NaN
# 610  10000.0  1.000000e+10  1.000000e+10
#
# [611 rows x 17 columns]

# %%
df['Experience'] = df['JobTitle'].apply(lambda x: 'Junior' if ('Junior' in x or 'Entry Level' in x or 'University Graduates' in x) else ('Senior' if 'Senior' in x else 'NA'))

keyword_mapping = {
    'Machine Learning Engineer': 'ML Engineer',
    'AI Engineer': 'AI Engineer',
    'Software Engineer': 'Software Engineer',
    'Frontend Engineer': 'Software Engineer',
    'Research Engineer': 'Research Engineer',
    'Staff Software Engineer': 'Software Engineer',
    'Principal Engineer': 'Software Engineer',
    'AI Designer': 'AI Engineer',
    'Applied Machine Learning Engineer': 'ML Engineer',
    'AI Solution Engineer': 'AI Engineer',
    'AI/ML Research Engineer': 'Research Engineer',
    'Architecture Energy Modeling Engineer': 'Software Engineer',
    'AI Machine Learning Engineer': 'ML Engineer',
    'ML Supercomputer Performance Software Engineer': 'Software Engineer',
    'Lead Engineer': 'Software Engineer',
    'AI Prompt Engineer': 'AI Engineer',
    'Research Scientist': 'Research Engineer',
    'Junior AI/ML Software Developer': 'AI Engineer',
    'Senior Software Engineer': 'Software Engineer',
    'Research Scientist/Engineer': 'Research Engineer',
    'AI Cybersecurity Engineer': 'AI Engineer',
    'Junior Software Engineer': 'Software Engineer',
    'Conversational AI / NLP Engineer': 'AI Engineer',
    'Computer Vision AI Engineer': 'AI Engineer',
    'Senior ML Engineer': 'ML Engineer',
    'Frontend Software Engineer': 'Software Engineer',
    'Principal Engineer, Machine Learning': 'ML Engineer',
    'Senior Staff Front-End Engineer': 'Software Engineer',
    'Senior AI/ML Engineer': 'ML Engineer',
    'AI/ML Engineer': 'ML Engineer',
    'Machine Learning Engineer (Entry Level)': 'ML Engineer',
    'AI/ML Cloud Engineer': 'AI Engineer'
}

df['Profession'] = df['JobTitle'].apply(lambda x: next((v for k, v in keyword_mapping.items() if k in x), 'NA'))

# %% [markdown]
# Let's add two new columns. One, 'Profession', which is like a simplification of the job title. We have a dict with the different main types of jobs. 'Experience' tell us the job's seniority.

# %%
df['AvgSalary'] = (df['MinSalary'] + df['MaxSalary']) / 2
df['AvgSize'] = (df['MinSize'] + df['MaxSize']) / 2
df['AvgRevenue'] = (df['MinRevenue'] + df['MaxRevenue']) / 2
df
# Out:
#     PublishedAgo  Rating                    Employer  \
# 0             5d     4.3    KGS Technology Group Inc
# 1             4d     4.2                    QSC, LLC
# 2           30d+     4.2      MIT Lincoln Laboratory
# 3             6d     4.2  Hewlett Packard Enterprise
# 4             2d     3.3                    Oran Inc
# ..           ...     ...                         ...
# 606           9d     4.0                      PayPal
# 607          12d     3.5                Eightfold.AI
# 608         30d+     4.4                       Adobe
# 609         30d+     4.5                       Curai
# 610           5d     4.3                   Microsoft
#
#                                JobTitle  Founded                    Type  \
# 0              Junior Software Engineer   2008.0       Company - Private
# 1                           AI Engineer   1968.0       Company - Private
# 2                           AI Engineer   1951.0  Nonprofit Organization
# 3                  AI Solution Engineer   2015.0        Company - Public
# 4                  AI/ML Cloud Engineer   2004.0       Company - Private
# ..                                  ...      ...                     ...
# 606        AI Machine Learning Engineer   1998.0        Company - Public
# 607           Machine Learning Engineer   2016.0       Company - Private
# 608         Research Scientist/Engineer   1982.0        Company - Public
# 609  Machine Learning Engineer (Remote)   2017.0       Company - Private
# 610                   Software Engineer   1975.0        Company - Public
#
#                                     Industry                   Sector  \
# 0    Information Technology Support Services   Information Technology
# 1                  Electronics Manufacturing            Manufacturing
# 2                        Aerospace & Defense      Aerospace & Defense
# 3    Information Technology Support Services   Information Technology
# 4                        Business Consulting  Management & Consulting
# ..                                       ...                      ...
# 606                  Internet & Web Services   Information Technology
# 607  Enterprise Software & Network Solutions   Information Technology
# 608            Computer Hardware Development   Information Technology
# 609               Hospitals & Health Clinics               Healthcare
# 610            Computer Hardware Development   Information Technology
#
#      MinSalary  MaxSalary  ...        Country  MinSize  MaxSize    MinRevenue  \
# 0         60.0       80.0  ...         Remote     51.0    200.0  1.000000e+06
# 1        102.0      147.0  ...         Remote    501.0   1000.0           NaN
# 2         94.0      138.0  ...  United States   1001.0   5000.0           NaN
# 3        123.0      283.0  ...  United States  10000.0  10000.0           NaN
# 4        140.0      140.0  ...         Remote      1.0     50.0  1.000000e+06
# ..         ...        ...  ...            ...      ...      ...           ...
# 606       97.0      234.0  ...  United States  10000.0  10000.0  1.000000e+10
# 607      121.0      163.0  ...  United States    501.0   1000.0           NaN
# 608      121.0      239.0  ...  United States  10000.0  10000.0  5.000000e+09
# 609      150.0      200.0  ...  United States     51.0    200.0           NaN
# 610       76.0      152.0  ...  United States  10000.0  10000.0  1.000000e+10
#
#        MaxRevenue  Experience         Profession AvgSalary  AvgSize  \
# 0    5.000000e+06      Junior  Software Engineer      70.0    125.5
# 1             NaN          NA        AI Engineer     124.5    750.5
# 2             NaN          NA        AI Engineer     116.0   3000.5
# 3             NaN          NA        AI Engineer     203.0  10000.0
# 4    5.000000e+06          NA        AI Engineer     140.0     25.5
# ..            ...         ...                ...       ...      ...
# 606  1.000000e+10          NA        ML Engineer     165.5  10000.0
# 607           NaN          NA        ML Engineer     142.0    750.5
# 608  1.000000e+10          NA  Research Engineer     180.0  10000.0
# 609           NaN          NA        ML Engineer     175.0    125.5
# 610  1.000000e+10          NA  Software Engineer     114.0  10000.0
#
#        AvgRevenue
# 0    3.000000e+06
# 1             NaN
# 2             NaN
# 3             NaN
# 4    3.000000e+06
# ..            ...
# 606  1.000000e+10
# 607           NaN
# 608  7.500000e+09
# 609           NaN
# 610  1.000000e+10
#
# [611 rows x 22 columns]

# %% [markdown]
# Add three new columns with the average values of the data that have Min and Max

# %%
df.describe()
# Out:
#            Rating      Founded   MinSalary   MaxSalary       MinSize  \
# count  611.000000   611.000000  611.000000  611.000000    611.000000
# mean     4.135025  1980.661211  125.746318  206.202291   7777.972177
# std      0.402228    39.132328   33.489114   56.258495   4063.557246
# min      3.300000  1861.000000   60.000000   80.000000      1.000000
# 25%      3.900000  1975.000000   97.000000  165.000000  10000.000000
# 50%      4.200000  1993.000000  133.000000  204.000000  10000.000000
# 75%      4.300000  2007.000000  146.500000  257.000000  10000.000000
# max      5.000000  2020.000000  196.000000  311.000000  10000.000000
#
#             MaxSize    MinRevenue    MaxRevenue   AvgSalary       AvgSize  \
# count    611.000000  4.990000e+02  4.990000e+02  611.000000    611.000000
# mean    7979.132570  5.800248e+09  7.850341e+09  165.974304   7878.552373
# std     3778.194868  4.090706e+09  3.272137e+09   41.956427   3905.564426
# min       50.000000  1.000000e+06  5.000000e+06   70.000000     25.500000
# 25%    10000.000000  1.000000e+09  5.000000e+09  142.000000  10000.000000
# 50%    10000.000000  5.000000e+09  1.000000e+10  173.500000  10000.000000
# 75%    10000.000000  1.000000e+10  1.000000e+10  195.500000  10000.000000
# max    10000.000000  1.000000e+10  1.000000e+10  253.500000  10000.000000
#
#          AvgRevenue
# count  4.990000e+02
# mean   6.825295e+09
# std    3.529978e+09
# min    3.000000e+06
# 25%    3.000000e+09
# 50%    7.500000e+09
# 75%    1.000000e+10
# max    1.000000e+10

# %%
df['Rating'].hist()
# Out:
# <Axes: >

# %%
df[['MinSalary', 'MaxSalary']].hist()
# Out:
# array([[<Axes: title={'center': 'MinSalary'}>,
#         <Axes: title={'center': 'MaxSalary'}>]], dtype=object)

# %%
fig, ax = plt.subplots()

min_salary = df['MinSalary']
max_salary = df['MaxSalary']

data = [min_salary, max_salary]

ax.boxplot(data, labels=['Minimun Salary', 'Maximun Salary'])

ax.set_xlabel('Salary')
ax.set_ylabel('Distribution')

plt.show()

# %% [markdown]
# We can see that the most popular salary is 10000+

# %%
correlation_matrix = df[df.select_dtypes(include=['int', 'float']).columns].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')

plt.subplots_adjust(left=0.15, bottom=0.15)

plt.show()

# %% [markdown]
# Here we can see the correlations between the different variables, but let's see them in a more simple way.

# %%
def get_redundant_pairs(df):
    '''Get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop = set()
    cols = df.select_dtypes(include=['int', 'float']).columns
    for i in range(0, len(cols)):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

def get_top_abs_correlations(df, n=5):
    correlation_matrix = df[df.select_dtypes(include=['int', 'float']).columns].corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    correlation_matrix = correlation_matrix.drop(labels=labels_to_drop).sort_values(ascending=False)
    return correlation_matrix[0:n]

print("Top Absolute Correlations")
print(get_top_abs_correlations(df, 20))
# Out:
# Top Absolute Correlations
# MinSize     AvgSize       0.996370
# MaxSize     AvgSize       0.995799
# MinSize     MaxSize       0.984389
# MinRevenue  AvgRevenue    0.967271
# MaxSalary   AvgSalary     0.962214
# MaxRevenue  AvgRevenue    0.948351
# MinSalary   AvgSalary     0.889248
# MinRevenue  MaxRevenue    0.836818
# MaxRevenue  AvgSize       0.769666
# MinSize     MaxRevenue    0.765658
# MaxSize     MaxRevenue    0.765481
# MinSalary   MaxSalary     0.731093
# AvgSize     AvgRevenue    0.633132
# MinSize     AvgRevenue    0.632144
# MaxSize     AvgRevenue    0.627078
# Rating      MaxRevenue    0.563161
# Founded     MinSalary     0.511520
# MinSize     MinRevenue    0.478541
# MinRevenue  AvgSize       0.477041
# MaxSize     MinRevenue    0.469939
# dtype: float64

# %%
df[df.select_dtypes(include=['int', 'float']).columns].corrwith(df['AvgSalary'])
# Out:
# Rating        0.282903
# Founded       0.455138
# MinSalary     0.889248
# MaxSalary     0.962214
# MinSize       0.206893
# MaxSize       0.173707
# MinRevenue   -0.011014
# MaxRevenue    0.202021
# AvgSalary     1.000000
# AvgSize       0.191652
# AvgRevenue    0.087251
# dtype: float64

# %%
df_cat = df[df.select_dtypes(exclude=['int', 'float']).columns]
df_cat
# Out:
#     PublishedAgo                    Employer  \
# 0             5d    KGS Technology Group Inc
# 1             4d                    QSC, LLC
# 2           30d+      MIT Lincoln Laboratory
# 3             6d  Hewlett Packard Enterprise
# 4             2d                    Oran Inc
# ..           ...                         ...
# 606           9d                      PayPal
# 607          12d                Eightfold.AI
# 608         30d+                       Adobe
# 609         30d+                       Curai
# 610           5d                   Microsoft
#
#                                JobTitle                    Type  \
# 0              Junior Software Engineer       Company - Private
# 1                           AI Engineer       Company - Private
# 2                           AI Engineer  Nonprofit Organization
# 3                  AI Solution Engineer        Company - Public
# 4                  AI/ML Cloud Engineer       Company - Private
# ..                                  ...                     ...
# 606        AI Machine Learning Engineer        Company - Public
# 607           Machine Learning Engineer       Company - Private
# 608         Research Scientist/Engineer        Company - Public
# 609  Machine Learning Engineer (Remote)       Company - Private
# 610                   Software Engineer        Company - Public
#
#                                     Industry                   Sector  \
# 0    Information Technology Support Services   Information Technology
# 1                  Electronics Manufacturing            Manufacturing
# 2                        Aerospace & Defense      Aerospace & Defense
# 3    Information Technology Support Services   Information Technology
# 4                        Business Consulting  Management & Consulting
# ..                                       ...                      ...
# 606                  Internet & Web Services   Information Technology
# 607  Enterprise Software & Network Solutions   Information Technology
# 608            Computer Hardware Development   Information Technology
# 609               Hospitals & Health Clinics               Healthcare
# 610            Computer Hardware Development   Information Technology
#
#               City   State        Country Experience         Profession
# 0           Remote  Remote         Remote     Junior  Software Engineer
# 1           Remote  Remote         Remote         NA        AI Engineer
# 2        Lexington      MA  United States         NA        AI Engineer
# 3         San Jose      CA  United States         NA        AI Engineer
# 4           Remote  Remote         Remote         NA        AI Engineer
# ..             ...     ...            ...        ...                ...
# 606       San Jose      CA  United States         NA        ML Engineer
# 607    Santa Clara      CA  United States         NA        ML Engineer
# 608       San Jose      CA  United States         NA  Research Engineer
# 609  San Francisco      CA  United States         NA        ML Engineer
# 610        Redmond      WA  United States         NA  Software Engineer
#
# [611 rows x 11 columns]

# %%
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()[:30]
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()

# %%
pd.pivot_table(df, index=['Profession', 'Experience'], values='AvgSalary')
# Out:
#                                AvgSalary
# Profession        Experience
# AI Engineer       Junior       74.500000
#                   NA          168.296154
#                   Senior      129.000000
# ML Engineer       Junior       90.000000
#                   NA          165.231214
#                   Senior      193.125000
# Research Engineer Junior      171.000000
#                   NA          128.372549
# Software Engineer Junior       70.000000
#                   NA          178.318725
#                   Senior      112.500000

# %% [markdown]
# # New Section

# %% [markdown]
# Clearly the senior salaries are higher, but we have a lot of NaN values.

# %%
pd.pivot_table(df, index=['State', 'Profession'], values='AvgSalary').sort_values('State', ascending=False)
# Out:
#                            AvgSalary
# State  Profession
# Remote Software Engineer  108.500000
#        ML Engineer        120.600000
#        AI Engineer        138.450000
#  WA    Software Engineer  155.673077
#        ML Engineer        195.500000
#  VA    ML Engineer         80.500000
#  TX    AI Engineer        195.500000
#  OH    Software Engineer  102.560000
#  NY    AI Engineer        130.000000
#        Software Engineer  151.500000
#        ML Engineer         90.000000
#  MN    Research Engineer   73.000000
#  MI    Software Engineer  171.000000
#        AI Engineer         92.500000
#  MD    AI Engineer        147.980769
#  MA    ML Engineer        137.500000
#        AI Engineer        116.000000
#  GA    ML Engineer        174.000000
#  DC    AI Engineer         74.500000
#  CA    ML Engineer        160.950000
#        Software Engineer  196.526471
#        Research Engineer  176.741935
#        AI Engineer        200.192308

# %%
pd.pivot_table(df, index=['State', 'Profession'], values='AvgSalary', aggfunc='count').sort_values('State', ascending=False)
# Out:
#                           AvgSalary
# State  Profession
# Remote Software Engineer         15
#        ML Engineer                5
#        AI Engineer                4
#  WA    Software Engineer         52
#        ML Engineer               26
#  VA    ML Engineer                1
#  TX    AI Engineer               26
#  OH    Software Engineer         25
#  NY    AI Engineer               25
#        Software Engineer          1
#        ML Engineer                1
#  MN    Research Engineer         24
#  MI    Software Engineer          3
#        AI Engineer                1
#  MD    AI Engineer               26
#  MA    ML Engineer                2
#        AI Engineer                1
#  GA    ML Engineer               23
#  DC    AI Engineer                3
#  CA    ML Engineer              120
#        Software Engineer        170
#        Research Engineer         31
#        AI Engineer               26

# %%
df.columns
# Out:
# Index(['PublishedAgo', 'Rating', 'Employer', 'JobTitle', 'Founded', 'Type',
#        'Industry', 'Sector', 'MinSalary', 'MaxSalary', 'City', 'State',
#        'Country', 'MinSize', 'MaxSize', 'MinRevenue', 'MaxRevenue',
#        'Experience', 'Profession', 'AvgSalary', 'AvgSize', 'AvgRevenue'],
#       dtype='object')

# %%
df_pivots = df[['Rating', 'Industry', 'Sector', 'AvgRevenue', 'AvgSize', 'Type', 'Employer', 'Founded', 'AvgSalary']]

# %%
for i in df_pivots.columns:
    print(pd.pivot_table(df_pivots,index=i, values = 'AvgSalary').sort_values('AvgSalary', ascending = False)) if i != 'AvgSalary' else None
# Out:
#          AvgSalary
# Rating
# 4.7     237.750000
# 3.9     185.957447
# 3.6     175.016129
# 4.5     173.466667
# 4.3     172.509091
# 5.0     169.832353
# 4.2     168.829670
# 3.5     155.200000
# 4.4     152.679487
# 4.1     141.166667
# 3.3     140.000000
# 4.9     135.000000
# 4.0     116.078947
# 3.4      74.500000
#                                           AvgSalary
# Industry
# Beauty & Personal Accessories Stores     203.500000
# Internet & Web Services                  178.647368
# Hospitals & Health Clinics               175.000000
# Health Care Products Manufacturing       171.500000
# Computer Hardware Development            171.033040
# Information Technology Support Services  169.629730
# Software Development                     168.500000
# Enterprise Software & Network Solutions  157.255000
# Transportation Equipment Manufacturing   153.088235
# Business Consulting                      151.931818
# Broadcast Media                          151.500000
# Telecommunications Services              147.500000
# Colleges & Universities                  137.500000
# Machinery Manufacturing                  135.000000
# Consumer Product Manufacturing           130.307692
# Banking & Lending                        130.000000
# Electronics Manufacturing                124.500000
# Aerospace & Defense                      103.000000
# Video Game Publishing                     87.500000
#                           AvgSalary
# Sector
# Retail & Wholesale       203.500000
# Healthcare               175.000000
# Information Technology   169.483405
# Management & Consulting  151.931818
# Telecommunications       147.500000
# Manufacturing            143.679688
# Education                137.500000
# Financial Services       130.000000
# Aerospace & Defense      103.000000
# Media & Communication     93.900000
#                AvgSalary
# AvgRevenue
# 7.500000e+09  198.037037
# 6.250000e+07  162.921875
# 3.000000e+09  162.436975
# 1.000000e+10  157.547085
# 3.000000e+06  103.750000
# 7.500000e+08   87.500000
# 1.500000e+07   84.450000
#           AvgSalary
# AvgSize
# 25.5     173.870968
# 10000.0  170.864894
# 750.5    153.736364
# 125.5    141.857692
# 350.5    140.142857
# 3000.5   117.681818
#                                  AvgSalary
# Type
# Company - Public                169.128205
# Company - Private               164.068667
# Nonprofit Organization          143.800000
# College / University            137.500000
# Subsidiary or Business Segment  130.000000
#                                   AvgSalary
# Employer
# NVIDIA                           237.750000
# Sephora USA                      203.500000
# Hewlett Packard Enterprise       203.000000
# Meta                             198.184211
# Adobe                            180.880000
# Microsoft                        175.718447
# MindsDB                          175.000000
# Curai                            175.000000
# Cyberhaven                       175.000000
# Runway AI                        175.000000
# Workday                          174.000000
# Stryker                          171.500000
# ITHAKA                           171.000000
# TikTok                           169.200000
# Palo Alto Networks               166.000000
# Discord                          165.000000
# PayPal                           164.833333
# Tesla                            153.088235
# Booz Allen Hamilton              152.500000
# ServiceNow                       152.000000
# Warner Music Group               151.500000
# Autodesk                         148.909091
# NOKIA                            147.500000
# Eightfold.AI                     142.730769
# Arize AI                         142.500000
# Oran Inc                         140.000000
# Harman International             138.000000
# MIT                              137.500000
# Snappyhires                      135.000000
# Snorkel AI                       135.000000
# Sony Electronics                 130.000000
# Alelo                            130.000000
# Cisco Systems                    129.000000
# QSC, LLC                         124.500000
# Zoom Video Communications, Inc.  117.000000
# Affinity.co                      117.000000
# MIT Lincoln Laboratory           116.000000
# Accede LLC                       114.300000
# FreightVerify                     92.500000
# SRC, Inc                          90.000000
# Honeywell                         88.081633
# Zynga                             87.500000
# PMAT                              80.500000
# Paradyme Management               74.500000
# KGS Technology Group Inc          70.000000
#           AvgSalary
# Founded
# 1993.0   237.750000
# 1969.0   203.500000
# 2004.0   195.575000
# 2015.0   178.298246
# 1975.0   175.718447
# 2018.0   175.000000
# 2017.0   175.000000
# 2005.0   173.360000
# 1941.0   171.500000
# 1982.0   171.111111
# 1995.0   171.000000
# 1998.0   164.833333
# 1914.0   152.500000
# 2016.0   147.875000
# 1865.0   147.500000
# 2003.0   146.410256
# 2020.0   142.500000
# 1980.0   138.000000
# 1861.0   137.500000
# 1946.0   130.000000
# 1984.0   129.000000
# 2019.0   124.650000
# 1968.0   124.500000
# 2011.0   117.000000
# 1951.0   116.000000
# 2014.0   113.750000
# 1957.0    90.000000
# 1885.0    88.081633
# 2007.0    86.800000
# 2008.0    70.000000

# %%
df.to_csv('data_eda.csv', index=False)
